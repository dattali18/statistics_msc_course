# %% [markdown]
# # Statistics for Data Mining (M.Sc.)
#
# In this part we will load the data from `"../data/wine_dataset_assignment.csv"` and perform some basic statistical analysis.

# %%
DATA_PATH = "../content/sample_data/"
FILE_PATH = DATA_PATH + "wine_dataset_assignment.csv"

# %%
# load the data using pandas
import pandas as pd

data = pd.read_csv(FILE_PATH)

# %%
# show the table

data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target target_name
# 0                          3.92   1065.0       0     class_0
# 1                          3.40   1050.0       0     class_0
# 2                          3.17   1185.0       0     class_0
# 3                          3.45   1480.0       0     class_0
# 4                          2.93    735.0       0     class_0

# %%
# print a list of attributes/columns in the dataset

attrs = data.columns.tolist()
for attr in attrs:
    print(attr)
# Out:
# alcohol
# malic_acid
# ash
# alcalinity_of_ash
# magnesium
# total_phenols
# flavanoids
# nonflavanoid_phenols
# proanthocyanins
# color_intensity
# hue
# od280/od315_of_diluted_wines
# proline
# target
# target_name

# %%
# print the dtype of each column

dtypes = data.dtypes
for attr, dtype in zip(attrs, dtypes):
    print(f"{attr}: {dtype}")
# Out:
# alcohol: float64
# malic_acid: float64
# ash: float64
# alcalinity_of_ash: float64
# magnesium: float64
# total_phenols: float64
# flavanoids: float64
# nonflavanoid_phenols: float64
# proanthocyanins: float64
# color_intensity: float64
# hue: float64
# od280/od315_of_diluted_wines: float64
# proline: float64
# target: int64
# target_name: object

# %% [markdown]
# ### Basic Statistical Analysis
#
# Perform initial statistical analyses where relevant, including:
#
# * Mean, variance, standard deviation, median
# * Mean absolute deviation
# * Range, midrange, percentage of errors, and relevant proportions

# %%
# perform statistical analysis on the numerical attributes

numerical_attrs = data.select_dtypes(include=['float64', 'int64']).columns.tolist()

for attr in numerical_attrs:
    col_data = data[attr]
    mean = col_data.mean()
    variance = col_data.var()
    std_dev = col_data.std()
    median = col_data.median()
    data_range = col_data.max() - col_data.min()
    midrange = (col_data.max() + col_data.min()) / 2

    print(f"Attribute: {attr}")
    print(f" Mean: {mean:.2f}")
    print(f" Variance: {variance:.2f}")
    print(f" Standard Deviation: {std_dev:.2f}")
    print(f" Median: {median:.2f}")
    print(f" Range: {data_range:.2f}")
    print(f" Midrange: {midrange:.2f}")
    print("-" * 40)
# Out:
# Attribute: alcohol
#  Mean: 13.00
#  Variance: 0.66
#  Standard Deviation: 0.81
#  Median: 13.05
#  Range: 3.80
#  Midrange: 12.93
# ----------------------------------------
# Attribute: malic_acid
#  Mean: 2.34
#  Variance: 1.25
#  Standard Deviation: 1.12
#  Median: 1.87
#  Range: 5.06
#  Midrange: 3.27
# ----------------------------------------
# Attribute: ash
#  Mean: 2.37
#  Variance: 0.08
#  Standard Deviation: 0.27
#  Median: 2.36
#  Range: 1.87
#  Midrange: 2.29
# ----------------------------------------
# Attribute: alcalinity_of_ash
#  Mean: 19.49
#  Variance: 11.15
#  Standard Deviation: 3.34
#  Median: 19.50
#  Range: 19.40
#  Midrange: 20.30
# ----------------------------------------
# Attribute: magnesium
#  Mean: 99.74
#  Variance: 203.99
#  Standard Deviation: 14.28
#  Median: 98.00
#  Range: 92.00
#  Midrange: 116.00
# ----------------------------------------
# Attribute: total_phenols
#  Mean: 2.30
#  Variance: 0.39
#  Standard Deviation: 0.63
#  Median: 2.35
#  Range: 2.90
#  Midrange: 2.43
# ----------------------------------------
# Attribute: flavanoids
#  Mean: 2.03
#  Variance: 1.00
#  Standard Deviation: 1.00
#  Median: 2.13
#  Range: 4.74
#  Midrange: 2.71
# ----------------------------------------
# Attribute: nonflavanoid_phenols
#  Mean: 0.36
#  Variance: 0.02
#  Standard Deviation: 0.12
#  Median: 0.34
#  Range: 0.53
#  Midrange: 0.40
# ----------------------------------------
# Attribute: proanthocyanins
#  Mean: 1.59
#  Variance: 0.33
#  Standard Deviation: 0.57
#  Median: 1.56
#  Range: 3.17
#  Midrange: 2.00
# ----------------------------------------
# Attribute: color_intensity
#  Mean: 5.06
#  Variance: 5.37
#  Standard Deviation: 2.32
#  Median: 4.69
#  Range: 11.72
#  Midrange: 7.14
# ----------------------------------------
# Attribute: hue
#  Mean: 0.96
#  Variance: 0.05
#  Standard Deviation: 0.23
#  Median: 0.96
#  Range: 1.23
#  Midrange: 1.09
# ----------------------------------------
# Attribute: od280/od315_of_diluted_wines
#  Mean: 2.61
#  Variance: 0.50
#  Standard Deviation: 0.71
#  Median: 2.78
#  Range: 2.73
#  Midrange: 2.63
# ----------------------------------------
# Attribute: proline
#  Mean: 746.89
#  Variance: 99166.72
#  Standard Deviation: 314.91
#  Median: 673.50
#  Range: 1402.00
#  Midrange: 979.00
# ----------------------------------------
# Attribute: target
#  Mean: 0.94
#  Variance: 0.60
#  Standard Deviation: 0.78
#  Median: 1.00
#  Range: 2.00
#  Midrange: 1.00
# ----------------------------------------

# %%
# create a df for the results
import numpy as np

results = []
for attr in numerical_attrs:
    col_data = data[attr]
    results.append({
        "Attribute": attr,
        "Mean": col_data.mean(),
        "Variance": col_data.var(),
        "Standard Deviation": col_data.std(),
        "Median": col_data.median(),
        "Range": col_data.max() - col_data.min(),
        "Midrange": (col_data.max() + col_data.min()) / 2
    })

# %%
# show the df
results_df = pd.DataFrame(results)

results_df
# Out:
#                        Attribute        Mean      Variance  \
# 0                        alcohol   13.000618      0.659062
# 1                     malic_acid    2.336348      1.248015
# 2                            ash    2.366517      0.075265
# 3              alcalinity_of_ash   19.494944     11.152686
# 4                      magnesium   99.741573    203.989335
# 5                  total_phenols    2.295112      0.391690
# 6                     flavanoids    2.029270      0.997719
# 7           nonflavanoid_phenols    0.361854      0.015489
# 8                proanthocyanins    1.590899      0.327595
# 9                color_intensity    5.058090      5.374449
# 10                           hue    0.957449      0.052245
# 11  od280/od315_of_diluted_wines    2.611685      0.504086
# 12                       proline  746.893258  99166.717355
# 13                        target    0.938202      0.600679
#
#     Standard Deviation   Median    Range  Midrange
# 0             0.811827   13.050     3.80    12.930
# 1             1.117146    1.865     5.06     3.270
# 2             0.274344    2.360     1.87     2.295
# 3             3.339564   19.500    19.40    20.300
# 4            14.282484   98.000    92.00   116.000
# 5             0.625851    2.355     2.90     2.430
# 6             0.998859    2.135     4.74     2.710
# 7             0.124453    0.340     0.53     0.395
# 8             0.572359    1.555     3.17     1.995
# 9             2.318286    4.690    11.72     7.140
# 10            0.228572    0.965     1.23     1.095
# 11            0.709990    2.780     2.73     2.635
# 12          314.907474  673.500  1402.00   979.000
# 13            0.775035    1.000     2.00     1.000

# %% [markdown]
# ### Frequency Analysis
#
# Create **frequency tables** including:
#
# * Frequency, relative frequency, cumulative frequency
# * Class boundaries (real and imaginary), class width
# * Median, interquartile range, and relevant percentiles (e.g., 0.1, 0.9)

# %%
import pandas as pd

selected_attr = numerical_attrs[1]
col_data = data[selected_attr].dropna()

n_bins = 10  # change as needed
binned = pd.cut(col_data, bins=n_bins, include_lowest=True)
freq_table = binned.value_counts().sort_index().reset_index()
freq_table.columns = ['Interval', 'Frequency']
freq_table['Relative Frequency'] = freq_table['Frequency'] / freq_table['Frequency'].sum()  # note .sum()
freq_table['Cumulative Frequency'] = freq_table['Frequency'].cumsum()

freq_table
# Out:
#          Interval  Frequency  Relative Frequency  Cumulative Frequency
# 0  (0.734, 1.246]         18            0.101124                    18
# 1  (1.246, 1.752]         59            0.331461                    77
# 2  (1.752, 2.258]         33            0.185393                   110
# 3  (2.258, 2.764]         16            0.089888                   126
# 4   (2.764, 3.27]         14            0.078652                   140
# 5   (3.27, 3.776]         11            0.061798                   151
# 6  (3.776, 4.282]         14            0.078652                   165
# 7  (4.282, 4.788]          7            0.039326                   172
# 8  (4.788, 5.294]          3            0.016854                   175
# 9    (5.294, 5.8]          3            0.016854                   178

# %%
# show the results
freq_table
# Out:
#          Interval  Frequency  Relative Frequency  Cumulative Frequency
# 0  (0.734, 1.246]         18            0.101124                    18
# 1  (1.246, 1.752]         59            0.331461                    77
# 2  (1.752, 2.258]         33            0.185393                   110
# 3  (2.258, 2.764]         16            0.089888                   126
# 4   (2.764, 3.27]         14            0.078652                   140
# 5   (3.27, 3.776]         11            0.061798                   151
# 6  (3.776, 4.282]         14            0.078652                   165
# 7  (4.282, 4.788]          7            0.039326                   172
# 8  (4.788, 5.294]          3            0.016854                   175
# 9    (5.294, 5.8]          3            0.016854                   178

# %%
import matplotlib.pyplot as plt

# freq_table assumed to have columns: 'Interval' (pd.Interval) and 'Frequency'
x_labels = freq_table['Interval'].astype(str)

plt.figure(figsize=(10, 5))
plt.bar(x_labels, freq_table['Frequency'], alpha=0.7, color='C0')
plt.xticks(rotation=45, ha='right')
plt.xlabel(selected_attr)
plt.ylabel('Frequency')
plt.title(f'Frequency distribution of {selected_attr} (binned)')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# requires 'Interval' column of Interval objects (from pd.cut)
midpoints = freq_table['Interval'].apply(lambda iv: iv.mid)
widths = freq_table['Interval'].apply(lambda iv: iv.right - iv.left)

plt.figure(figsize=(10, 5))
plt.bar(midpoints, freq_table['Frequency'], width=widths, align='center', alpha=0.7, color='C0', edgecolor='k')
plt.xlabel(selected_attr)
plt.ylabel('Frequency')
plt.title(f'Frequency distribution of {selected_attr} (midpoints)')
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))
ax2 = ax1.twinx()

# bars (midpoint version)
ax1.bar(midpoints, freq_table['Frequency'], width=widths, alpha=0.7, color='C0', edgecolor='k')
ax1.set_ylabel('Frequency')

# cumulative (as percent)
cum_pct = freq_table['Frequency'].cumsum() / freq_table['Frequency'].sum() * 100
ax2.plot(midpoints, cum_pct, color='C1', marker='o')
ax2.set_ylabel('Cumulative frequency (%)')

ax1.set_xlabel(selected_attr)
ax1.set_title(f'Frequency and cumulative (%) of {selected_attr}')
plt.tight_layout()
plt.show()

# %%
# create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(freq_table['Frequency'], labels=x_labels, autopct='%1.1f', startangle=140)
plt.title(f'Frequency distribution of {selected_attr} (pie chart)')
plt.show()

# %% [markdown]
# # Finish Step 4: Mean Absolute Deviation & Coefficient of Variation

# %%
# Add this to your Basic Statistical Analysis section
import pandas as pd

# Select your numerical attributes
numerical_attrs = data.select_dtypes(include=['float64', 'int64']).columns.tolist()

stats_results = []

for attr in numerical_attrs:
    col_data = data[attr]

    # Calculate Mean Absolute Deviation (MAD)
    # Note: (x - mean).abs().mean() is the standard formula
    mad = (col_data - col_data.mean()).abs().mean()

    # Calculate Coefficient of Variation (CV) - often treated as % of error relative to mean
    # CV = (Standard Deviation / Mean) * 100
    mean_val = col_data.mean()
    std_dev = col_data.std()
    cv = (std_dev / mean_val) * 100 if mean_val != 0 else 0

    stats_results.append({
        "Attribute": attr,
        "MAD": mad,
        "Coeff of Variation (%)": cv
    })

# Display new stats
pd.DataFrame(stats_results)
# Out:
#                        Attribute         MAD  Coeff of Variation (%)
# 0                        alcohol    0.688462                6.244523
# 1                     malic_acid    0.920277               47.815905
# 2                            ash    0.209208               11.592734
# 3              alcalinity_of_ash    2.595001               17.130410
# 4                      magnesium   10.999243               14.319489
# 5                  total_phenols    0.536288               27.268863
# 6                     flavanoids    0.858878               49.222570
# 7           nonflavanoid_phenols    0.104696               34.393253
# 8                proanthocyanins    0.445893               35.977074
# 9                color_intensity    1.835831               45.833228
# 10                           hue    0.186851               23.872965
# 11  od280/od315_of_diluted_wines    0.611738               27.185144
# 12                       proline  259.332344               42.162313
# 13                        target    0.621954               82.608520

# %% [markdown]
# Finish Step 5: Specific Percentiles

# %%
# Calculate specific percentiles for all columns
percentiles = data[numerical_attrs].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
print("Percentiles (10th, 25th, Median, 75th, 90th):")
print(percentiles)
# Out:
# Percentiles (10th, 25th, Median, 75th, 90th):
#       alcohol  malic_acid     ash  alcalinity_of_ash  magnesium  \
# 0.10  11.9330      1.2470  2.0000               16.0       85.0
# 0.25  12.3625      1.6025  2.2100               17.2       88.0
# 0.50  13.0500      1.8650  2.3600               19.5       98.0
# 0.75  13.6775      3.0825  2.5575               21.5      107.0
# 0.90  14.1000      3.9830  2.7000               24.0      118.0
#
#       total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0.10         1.4710       0.607                0.2170            0.854
# 0.25         1.7425       1.205                0.2700            1.250
# 0.50         2.3550       2.135                0.3400            1.555
# 0.75         2.8000       2.875                0.4375            1.950
# 0.90         3.0440       3.233                0.5300            2.305
#
#       color_intensity     hue  od280/od315_of_diluted_wines  proline  target
# 0.10            2.549  0.6100                        1.5800    406.7     0.0
# 0.25            3.220  0.7825                        1.9375    500.5     0.0
# 0.50            4.690  0.9650                        2.7800    673.5     1.0
# 0.75            6.200  1.1200                        3.1700    985.0     2.0
# 0.90            8.530  1.2330                        3.4560   1261.5     2.0

# %% [markdown]
# Finish Step 6: Frequency Polygon

# %%
import matplotlib.pyplot as plt
import numpy as np

# Choose a variable to visualize, e.g., 'alcohol'
target_col = data['alcohol']

# Create histogram data first
counts, bin_edges = np.histogram(target_col, bins=10)

# Calculate bin midpoints
bin_midpoints = 0.5 * (bin_edges[1:] + bin_edges[:-1])

# Plot Frequency Polygon
plt.figure(figsize=(10, 6))
plt.plot(bin_midpoints, counts, marker='o', linestyle='-', color='b')
plt.title('Frequency Polygon for Alcohol Content')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Step 7: Z-Scores (Standard Scores)

# %%
# 1. Choose 3 variables
selected_vars = ['alcohol', 'malic_acid', 'ash']

# 2. Choose specific objects (e.g., the first 5 wines/rows)
subset = data.loc[0:4, selected_vars].copy()

# 3. Calculate Z-Scores: (Value - Mean) / Standard Deviation
# We calculate using the Mean/Std of the WHOLE dataset
z_scores = pd.DataFrame()

for col in selected_vars:
    col_mean = data[col].mean()
    col_std = data[col].std()

    # Create a new column for the Z-score
    z_scores[f'{col}_zscore'] = (subset[col] - col_mean) / col_std

# Display the specific objects and their Z-scores
print("Z-Scores for the first 5 objects on 3 variables:")
print(z_scores)
# Out:
# Z-Scores for the first 5 objects on 3 variables:
#    alcohol_zscore  malic_acid_zscore  ash_zscore
# 0        1.514341          -0.560668    0.231400
# 1        0.245597          -0.498009   -0.825667
# 2        0.196325           0.021172    1.106214
# 3        1.686791          -0.345835    0.486554
# 4        0.294868           0.227053    1.835226
